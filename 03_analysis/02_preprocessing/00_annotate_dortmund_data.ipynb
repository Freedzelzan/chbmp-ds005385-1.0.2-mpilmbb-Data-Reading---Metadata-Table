# %%
import os, sys
import csv
import numpy as np
import matplotlib.pyplot as plt
import mne
import glob

# %%
DIR_DATA = "/Users/Gesine/Documents/01__Job/03_Wissenschaft/chbmp-ds005385-1.0.2-mpilmbb-Data-Reading---Metadata-Table/02_data"
BASE_DIR_DORT = "/Users/Gesine/Documents/01__Job/03_Wissenschaft/chbmp-ds005385-1.0.2-mpilmbb-Data-Reading---Metadata-Table/02_data/00_download/ds005385-1.0.2"

# %%
output_dir = f"{DIR_DATA}/01_prepdata/00_dortmund_annotations_artifacts"
search_pattern = os.path.join(BASE_DIR_DORT, "sub-*", "**", "eeg", "*task-EyesClosed*.edf")

# %%
edf_files = sorted(glob.glob(search_pattern, recursive=True))

# %%
# %matplotlib qt
raw = mne.io.read_raw_edf(edf_files[0], preload=True)
raw.plot()
# Out:
# Extracting EDF parameters from /Users/Gesine/Documents/01__Job/03_Wissenschaft/chbmp-ds005385-1.0.2-mpilmbb-Data-Reading---Metadata-Table/02_data/00_download/ds005385-1.0.2/sub-001/ses-1/eeg/sub-001_ses-1_task-EyesClosed_acq-post_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 192999  =      0.000 ...   192.999 secs...
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 2940x1672 with 4 Axes>
# Channels marked as bad:
# none

# %%
print(raw.ch_names)
# Out:
# ['Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'T7', 'C3', 'Cz', 'C4', 'T8', 'TP9', 'CP5', 'CP1', 'CP2', 'CP6', 'TP10', 'P7', 'P3', 'Pz', 'P4', 'P8', 'PO9', 'O1', 'Oz', 'O2', 'PO10', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F1', 'F2', 'F6', 'FT9', 'FT7', 'FC3', 'FC4', 'FT8', 'FT10', 'C5', 'C1', 'C2', 'C6', 'TP7', 'CP3', 'CPz', 'CP4', 'TP8', 'P5', 'P1', 'P2', 'P6', 'PO7', 'PO3', 'POz', 'PO4', 'PO8', 'Status']

# %%
raw['Status']
# Out:
# (array([[1.00000e+00, 0.00000e+00, 0.00000e+00, ..., 1.20414e+05,
#          1.20414e+05, 1.20414e+05]]),
#  array([0.00000e+00, 1.00000e-03, 2.00000e-03, ..., 1.92997e+02,
#         1.92998e+02, 1.92999e+02]))
